# %%
import pandas as pd
df = pd.read_csv('/Users/jono/Downloads/disabled_onboards.csv')
df.head()
# Out:
#   COUNTRY_NAME             ONBOARDING_AREA       CITY  DRIVER_ID  \
# 0           UK                    Coventry   Coventry    1001618
# 1           UK                 Basingstoke     London    1001566
# 2           UK                 Basingstoke    Cardiff    1001567
# 3           UK                   Camberley  Camberley    1001568
# 4           UK  London - Lambeth & Brixton     London    1001570
#
#   ORDERS_DELIVERED_CUMULATIVE RIDER_ADMIN_STATUS_NOTE CUR_ADMIN_STATUS  \
# 0                           5                      \N               \N
# 1                         \\N                      \N               \N
# 2                           3                      \N               \N
# 3                          19                      \N               \N
# 4                         \\N                      \N               \N
#
#   STATUS_DATE ONBOARDING_AT_DATE CREATED_IN_RIDER_ADMIN_AT_DATE  \
# 0  2025-04-17         2025-04-17                     2025-04-17
# 1  2025-04-17         2025-04-17                     2025-04-17
# 2  2025-04-17         2025-04-17                     2025-04-17
# 3  2025-04-17         2025-04-17                     2025-04-17
# 4  2025-04-17         2025-04-17                     2025-04-17
#
#    DAYS_SINCE_ONBOARDING  DAYS_SINCE_ONBOARD_STATUS_CHANGE VEHICLE_TYPE
# 0                     14                                 0           BI
# 1                     14                                 0           BI
# 2                     14                                 0           BI
# 3                     14                                 0           EB
# 4                     14                                 0           SC

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Read the CSV file
df = pd.read_csv('/Users/jono/Downloads/disabled_onboards.csv')
print("\nFirst few rows of the data:")
print(df.head())

# Clean the data
df['ORDERS_DELIVERED_CUMULATIVE'] = df['ORDERS_DELIVERED_CUMULATIVE'].replace(['\\N', '\\\\N'], 0)
df['ORDERS_DELIVERED_CUMULATIVE'] = pd.to_numeric(df['ORDERS_DELIVERED_CUMULATIVE'], errors='coerce').fillna(0)

# Convert date columns to datetime
date_columns = ['STATUS_DATE', 'ONBOARDING_AT_DATE', 'CREATED_IN_RIDER_ADMIN_AT_DATE']
for col in date_columns:
    df[col] = pd.to_datetime(df[col])

# Function to check if a rider was previously disabled/terminated
def was_previously_disabled(group):
    if len(group) > 1:
        statuses = group['CUR_ADMIN_STATUS'].tolist()
        return any(status in ['DISABLED', 'TERMINATED'] for status in statuses if status != '\\N')
    return False

# Function to analyze rider status
def analyze_rider_status(df):
    # Active riders (status is null)
    active_riders = df[df['CUR_ADMIN_STATUS'] == '\\N']
    
    # Disabled/Terminated riders
    disabled_riders = df[df['CUR_ADMIN_STATUS'].isin(['DISABLED', 'TERMINATED'])]
    
    # Riders with grace period expired
    grace_period_expired = df[
        df['RIDER_ADMIN_STATUS_NOTE'].str.contains('conditional onboarding grace period expired', 
                                                  case=False, na=False)
    ]
    
    # Reactivated riders (previously disabled/terminated, now active)
    reactivated_riders = df.groupby('DRIVER_ID').filter(was_previously_disabled)
    reactivated_riders = reactivated_riders[reactivated_riders['CUR_ADMIN_STATUS'] == '\\N']
    
    return {
        'active': active_riders,
        'disabled': disabled_riders,
        'grace_period_expired': grace_period_expired,
        'reactivated': reactivated_riders
    }

# Function to analyze orders
def analyze_orders(df):
    return {
        'with_orders': df[df['ORDERS_DELIVERED_CUMULATIVE'] > 0],
        'without_orders': df[df['ORDERS_DELIVERED_CUMULATIVE'] == 0]
    }

print("\n=== OVERALL ANALYSIS ===")
status_groups = analyze_rider_status(df)
print(f"Total Riders: {len(df)}")
print(f"Active Riders: {len(status_groups['active'])}")
print(f"Disabled/Terminated Riders: {len(status_groups['disabled'])}")
print(f"Grace Period Expired: {len(status_groups['grace_period_expired'])}")
print(f"Reactivated Riders: {len(status_groups['reactivated'])}")

print("\n=== ORDER ANALYSIS ===")
disabled_orders = analyze_orders(status_groups['disabled'])
reactivated_orders = analyze_orders(status_groups['reactivated'])

print("Disabled/Terminated Riders:")
print(f"- With Orders: {len(disabled_orders['with_orders'])}")
print(f"- Without Orders: {len(disabled_orders['without_orders'])}")

print("\nReactivated Riders:")
print(f"- With Orders: {len(reactivated_orders['with_orders'])}")
print(f"- Without Orders: {len(reactivated_orders['without_orders'])}")

print("\n=== ANALYSIS BY ONBOARDING AREA ===")
for area in df['ONBOARDING_AREA'].unique():
    area_df = df[df['ONBOARDING_AREA'] == area]
    area_status = analyze_rider_status(area_df)
    
    print(f"\n{area}:")
    print(f"Total Riders: {len(area_df)}")
    print(f"Active: {len(area_status['active'])}")
    print(f"Disabled/Terminated: {len(area_status['disabled'])}")
    print(f"Grace Period Expired: {len(area_status['grace_period_expired'])}")
    print(f"Reactivated: {len(area_status['reactivated'])}")

print("\n=== ANALYSIS BY VEHICLE TYPE ===")
for vtype in df['VEHICLE_TYPE'].unique():
    vtype_df = df[df['VEHICLE_TYPE'] == vtype]
    vtype_status = analyze_rider_status(vtype_df)
    
    print(f"\n{vtype}:")
    print(f"Total Riders: {len(vtype_df)}")
    print(f"Active: {len(vtype_status['active'])}")
    print(f"Disabled/Terminated: {len(vtype_status['disabled'])}")
    print(f"Grace Period Expired: {len(vtype_status['grace_period_expired'])}")
    print(f"Reactivated: {len(vtype_status['reactivated'])}")
# Out:
# First few rows of the data:
#   COUNTRY_NAME             ONBOARDING_AREA       CITY  DRIVER_ID  \
# 0           UK                    Coventry   Coventry    1001618
# 1           UK                 Basingstoke     London    1001566
# 2           UK                 Basingstoke    Cardiff    1001567
# 3           UK                   Camberley  Camberley    1001568
# 4           UK  London - Lambeth & Brixton     London    1001570
#
#   ORDERS_DELIVERED_CUMULATIVE RIDER_ADMIN_STATUS_NOTE CUR_ADMIN_STATUS  \
# 0                           5                      \N               \N
# 1                         \\N                      \N               \N
# 2                           3                      \N               \N
# 3                          19                      \N               \N
# 4                         \\N                      \N               \N
#
#   STATUS_DATE ONBOARDING_AT_DATE CREATED_IN_RIDER_ADMIN_AT_DATE  \
# 0  2025-04-17         2025-04-17                     2025-04-17
# 1  2025-04-17         2025-04-17                     2025-04-17
# 2  2025-04-17         2025-04-17                     2025-04-17
# 3  2025-04-17         2025-04-17                     2025-04-17
# 4  2025-04-17         2025-04-17                     2025-04-17
#
#    DAYS_SINCE_ONBOARDING  DAYS_SINCE_ONBOARD_STATUS_CHANGE VEHICLE_TYPE
# 0                     14                                 0           BI
# 1                     14                                 0           BI
# 2                     14                                 0           BI
# 3                     14                                 0           EB
# 4                     14                                 0           SC
#
# === OVERALL ANALYSIS ===
# Total Riders: 22151
# Active Riders: 16016
# Disabled/Terminated Riders: 4197
# Grace Period Expired: 3005
# Reactivated Riders: 3358
#
# === ORDER ANALYSIS ===
# Disabled/Terminated Riders:
# - With Orders: 3231
# - Without Orders: 966
#
# Reactivated Riders:
# - With Orders: 757
# - Without Orders: 2601
#
# === ANALYSIS BY ONBOARDING AREA ===
#
# Coventry:
# Total Riders: 112
# Active: 82
# Disabled/Terminated: 22
# Grace Period Expired: 11
# Reactivated: 14
#
# Basingstoke:
# Total Riders: 162
# Active: 106
# Disabled/Terminated: 43
# Grace Period Expired: 32
# Reactivated: 34
#
# Camberley:
# Total Riders: 39
# Active: 26
# Disabled/Terminated: 9
# Grace Period Expired: 5
# Reactivated: 5
#
# London - Lambeth & Brixton:
# Total Riders: 1055
# Active: 690
# Disabled/Terminated: 261
# Grace Period Expired: 181
# Reactivated: 198
#
# Edinburgh:
# Total Riders: 516
# Active: 332
# Disabled/Terminated: 117
# Grace Period Expired: 90
# Reactivated: 94
#
# Peterborough:
# Total Riders: 28
# Active: 24
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 4
#
# Cork:
# Total Riders: 265
# Active: 257
# Disabled/Terminated: 7
# Grace Period Expired: 0
# Reactivated: 6
#
# Chelmsford:
# Total Riders: 88
# Active: 57
# Disabled/Terminated: 18
# Grace Period Expired: 15
# Reactivated: 16
#
# Dublin:
# Total Riders: 1409
# Active: 1388
# Disabled/Terminated: 15
# Grace Period Expired: 0
# Reactivated: 13
#
# London - Richmond & Hounslow:
# Total Riders: 266
# Active: 205
# Disabled/Terminated: 41
# Grace Period Expired: 26
# Reactivated: 33
#
# Truro:
# Total Riders: 28
# Active: 20
# Disabled/Terminated: 5
# Grace Period Expired: 4
# Reactivated: 4
#
# London - Greenwich & Bromley:
# Total Riders: 154
# Active: 119
# Disabled/Terminated: 22
# Grace Period Expired: 12
# Reactivated: 18
#
# Newquay:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Brentwood:
# Total Riders: 46
# Active: 40
# Disabled/Terminated: 6
# Grace Period Expired: 4
# Reactivated: 5
#
# Galway:
# Total Riders: 197
# Active: 195
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Leeds:
# Total Riders: 149
# Active: 129
# Disabled/Terminated: 18
# Grace Period Expired: 11
# Reactivated: 14
#
# London - Enfield & Barnet:
# Total Riders: 127
# Active: 100
# Disabled/Terminated: 18
# Grace Period Expired: 12
# Reactivated: 15
#
# Farnborough:
# Total Riders: 66
# Active: 42
# Disabled/Terminated: 15
# Grace Period Expired: 10
# Reactivated: 10
#
# Northampton:
# Total Riders: 47
# Active: 41
# Disabled/Terminated: 4
# Grace Period Expired: 1
# Reactivated: 4
#
# Wokingham:
# Total Riders: 38
# Active: 28
# Disabled/Terminated: 7
# Grace Period Expired: 6
# Reactivated: 6
#
# Horsham:
# Total Riders: 180
# Active: 138
# Disabled/Terminated: 31
# Grace Period Expired: 22
# Reactivated: 25
#
# Harlow:
# Total Riders: 51
# Active: 32
# Disabled/Terminated: 12
# Grace Period Expired: 8
# Reactivated: 9
#
# Manchester - Ashton-under-Lyne:
# Total Riders: 33
# Active: 22
# Disabled/Terminated: 6
# Grace Period Expired: 4
# Reactivated: 5
#
# Manchester - Wilmslow:
# Total Riders: 23
# Active: 20
# Disabled/Terminated: 3
# Grace Period Expired: 3
# Reactivated: 3
#
# Bath:
# Total Riders: 106
# Active: 61
# Disabled/Terminated: 34
# Grace Period Expired: 24
# Reactivated: 25
#
# London - Barnet & Harrow:
# Total Riders: 236
# Active: 201
# Disabled/Terminated: 23
# Grace Period Expired: 5
# Reactivated: 19
#
# London - Elmbridge:
# Total Riders: 165
# Active: 121
# Disabled/Terminated: 28
# Grace Period Expired: 22
# Reactivated: 23
#
# Staines:
# Total Riders: 8
# Active: 6
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Glasgow:
# Total Riders: 187
# Active: 150
# Disabled/Terminated: 25
# Grace Period Expired: 14
# Reactivated: 20
#
# Bury St Edmunds:
# Total Riders: 48
# Active: 29
# Disabled/Terminated: 14
# Grace Period Expired: 10
# Reactivated: 10
#
# Oxford:
# Total Riders: 209
# Active: 153
# Disabled/Terminated: 36
# Grace Period Expired: 27
# Reactivated: 30
#
# Brighton:
# Total Riders: 127
# Active: 102
# Disabled/Terminated: 19
# Grace Period Expired: 13
# Reactivated: 12
#
# Newbury:
# Total Riders: 52
# Active: 34
# Disabled/Terminated: 12
# Grace Period Expired: 10
# Reactivated: 11
#
# London - Camden, Hackney & Islington:
# Total Riders: 1851
# Active: 1194
# Disabled/Terminated: 463
# Grace Period Expired: 347
# Reactivated: 361
#
# London - Wandsworth, Kingston & Merton:
# Total Riders: 1008
# Active: 668
# Disabled/Terminated: 232
# Grace Period Expired: 148
# Reactivated: 170
#
# Witham:
# Total Riders: 65
# Active: 49
# Disabled/Terminated: 11
# Grace Period Expired: 11
# Reactivated: 11
#
# Falmouth:
# Total Riders: 90
# Active: 59
# Disabled/Terminated: 24
# Grace Period Expired: 18
# Reactivated: 18
#
# Crawley:
# Total Riders: 82
# Active: 57
# Disabled/Terminated: 19
# Grace Period Expired: 12
# Reactivated: 14
#
# London - Hammersmith, Fulham and Ealing:
# Total Riders: 2574
# Active: 1682
# Disabled/Terminated: 631
# Grace Period Expired: 460
# Reactivated: 493
#
# Harrogate:
# Total Riders: 27
# Active: 25
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Colchester:
# Total Riders: 108
# Active: 75
# Disabled/Terminated: 21
# Grace Period Expired: 13
# Reactivated: 15
#
# Maidstone:
# Total Riders: 87
# Active: 58
# Disabled/Terminated: 23
# Grace Period Expired: 18
# Reactivated: 18
#
# York:
# Total Riders: 148
# Active: 98
# Disabled/Terminated: 30
# Grace Period Expired: 23
# Reactivated: 24
#
# St Andrews:
# Total Riders: 50
# Active: 37
# Disabled/Terminated: 9
# Grace Period Expired: 8
# Reactivated: 8
#
# Chichester:
# Total Riders: 48
# Active: 38
# Disabled/Terminated: 8
# Grace Period Expired: 7
# Reactivated: 7
#
# Telford:
# Total Riders: 31
# Active: 27
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Canterbury:
# Total Riders: 55
# Active: 35
# Disabled/Terminated: 15
# Grace Period Expired: 12
# Reactivated: 12
#
# Braintree:
# Total Riders: 137
# Active: 90
# Disabled/Terminated: 29
# Grace Period Expired: 20
# Reactivated: 21
#
# Guildford:
# Total Riders: 272
# Active: 182
# Disabled/Terminated: 56
# Grace Period Expired: 47
# Reactivated: 49
#
# Milton Keynes:
# Total Riders: 28
# Active: 28
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Plymouth:
# Total Riders: 248
# Active: 162
# Disabled/Terminated: 60
# Grace Period Expired: 50
# Reactivated: 53
#
# Stockport:
# Total Riders: 64
# Active: 48
# Disabled/Terminated: 10
# Grace Period Expired: 7
# Reactivated: 8
#
# Winchester:
# Total Riders: 89
# Active: 60
# Disabled/Terminated: 20
# Grace Period Expired: 15
# Reactivated: 15
#
# Bristol:
# Total Riders: 245
# Active: 165
# Disabled/Terminated: 60
# Grace Period Expired: 41
# Reactivated: 48
#
# Reading:
# Total Riders: 91
# Active: 72
# Disabled/Terminated: 14
# Grace Period Expired: 3
# Reactivated: 9
#
# Woking:
# Total Riders: 160
# Active: 107
# Disabled/Terminated: 39
# Grace Period Expired: 27
# Reactivated: 30
#
# Newport:
# Total Riders: 19
# Active: 14
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 3
#
# Bexhill-on-Sea:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Saint Austell:
# Total Riders: 12
# Active: 10
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Exeter:
# Total Riders: 261
# Active: 183
# Disabled/Terminated: 50
# Grace Period Expired: 39
# Reactivated: 44
#
# London - Croydon:
# Total Riders: 287
# Active: 227
# Disabled/Terminated: 36
# Grace Period Expired: 29
# Reactivated: 34
#
# Dartford:
# Total Riders: 9
# Active: 8
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# St Albans:
# Total Riders: 31
# Active: 27
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 3
#
# Luton:
# Total Riders: 10
# Active: 10
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Billericay:
# Total Riders: 20
# Active: 17
# Disabled/Terminated: 2
# Grace Period Expired: 1
# Reactivated: 1
#
# London - Ruislip:
# Total Riders: 39
# Active: 31
# Disabled/Terminated: 4
# Grace Period Expired: 3
# Reactivated: 4
#
# Southend on sea:
# Total Riders: 31
# Active: 20
# Disabled/Terminated: 7
# Grace Period Expired: 3
# Reactivated: 5
#
# Hemel Hempstead:
# Total Riders: 18
# Active: 18
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Newcastle:
# Total Riders: 123
# Active: 99
# Disabled/Terminated: 15
# Grace Period Expired: 10
# Reactivated: 15
#
# Southampton:
# Total Riders: 89
# Active: 73
# Disabled/Terminated: 10
# Grace Period Expired: 5
# Reactivated: 9
#
# Wigan:
# Total Riders: 23
# Active: 21
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Stoke-on-Trent:
# Total Riders: 45
# Active: 41
# Disabled/Terminated: 3
# Grace Period Expired: 0
# Reactivated: 3
#
# Cheltenham:
# Total Riders: 102
# Active: 66
# Disabled/Terminated: 24
# Grace Period Expired: 16
# Reactivated: 19
#
# London - Hillingdon:
# Total Riders: 57
# Active: 50
# Disabled/Terminated: 6
# Grace Period Expired: 3
# Reactivated: 5
#
# Bournemouth:
# Total Riders: 57
# Active: 51
# Disabled/Terminated: 4
# Grace Period Expired: 4
# Reactivated: 4
#
# Belfast:
# Total Riders: 170
# Active: 93
# Disabled/Terminated: 68
# Grace Period Expired: 55
# Reactivated: 58
#
# Cardiff:
# Total Riders: 46
# Active: 36
# Disabled/Terminated: 8
# Grace Period Expired: 3
# Reactivated: 6
#
# Royal Leamington Spa:
# Total Riders: 60
# Active: 35
# Disabled/Terminated: 19
# Grace Period Expired: 12
# Reactivated: 12
#
# London - Havering:
# Total Riders: 7
# Active: 7
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Godalming:
# Total Riders: 108
# Active: 79
# Disabled/Terminated: 18
# Grace Period Expired: 12
# Reactivated: 13
#
# Bedford:
# Total Riders: 49
# Active: 43
# Disabled/Terminated: 5
# Grace Period Expired: 3
# Reactivated: 4
#
# Norwich:
# Total Riders: 272
# Active: 186
# Disabled/Terminated: 53
# Grace Period Expired: 45
# Reactivated: 47
#
# Mansfield:
# Total Riders: 78
# Active: 64
# Disabled/Terminated: 8
# Grace Period Expired: 8
# Reactivated: 8
#
# Northwich:
# Total Riders: 36
# Active: 27
# Disabled/Terminated: 5
# Grace Period Expired: 3
# Reactivated: 4
#
# London - Southwark, Lewisham & Bromley:
# Total Riders: 1459
# Active: 953
# Disabled/Terminated: 330
# Grace Period Expired: 260
# Reactivated: 276
#
# London Central - Westminster & Tower Bridge:
# Total Riders: 1991
# Active: 1339
# Disabled/Terminated: 419
# Grace Period Expired: 309
# Reactivated: 332
#
# Worcester:
# Total Riders: 48
# Active: 34
# Disabled/Terminated: 11
# Grace Period Expired: 7
# Reactivated: 8
#
# Basildon:
# Total Riders: 11
# Active: 8
# Disabled/Terminated: 2
# Grace Period Expired: 1
# Reactivated: 2
#
# Chesham:
# Total Riders: 24
# Active: 23
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Reigate:
# Total Riders: 16
# Active: 12
# Disabled/Terminated: 3
# Grace Period Expired: 1
# Reactivated: 2
#
# Limerick:
# Total Riders: 93
# Active: 91
# Disabled/Terminated: 2
# Grace Period Expired: 0
# Reactivated: 1
#
# London - Redbridge & Waltham Forest:
# Total Riders: 120
# Active: 103
# Disabled/Terminated: 12
# Grace Period Expired: 0
# Reactivated: 11
#
# Warrington:
# Total Riders: 13
# Active: 12
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Didcot:
# Total Riders: 23
# Active: 17
# Disabled/Terminated: 5
# Grace Period Expired: 4
# Reactivated: 4
#
# Aylesford:
# Total Riders: 13
# Active: 9
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Broxbourne:
# Total Riders: 6
# Active: 4
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Haslemere:
# Total Riders: 54
# Active: 34
# Disabled/Terminated: 13
# Grace Period Expired: 9
# Reactivated: 11
#
# High Wycombe:
# Total Riders: 25
# Active: 19
# Disabled/Terminated: 4
# Grace Period Expired: 1
# Reactivated: 4
#
# Hertford:
# Total Riders: 22
# Active: 16
# Disabled/Terminated: 5
# Grace Period Expired: 4
# Reactivated: 4
#
# Gloucester:
# Total Riders: 36
# Active: 31
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 2
#
# Manchester:
# Total Riders: 208
# Active: 169
# Disabled/Terminated: 24
# Grace Period Expired: 14
# Reactivated: 20
#
# Taunton Central:
# Total Riders: 14
# Active: 12
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Margate:
# Total Riders: 22
# Active: 22
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Burnley:
# Total Riders: 48
# Active: 38
# Disabled/Terminated: 6
# Grace Period Expired: 6
# Reactivated: 6
#
# Chesterfield:
# Total Riders: 175
# Active: 106
# Disabled/Terminated: 44
# Grace Period Expired: 29
# Reactivated: 33
#
# Grays:
# Total Riders: 5
# Active: 5
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Crewe:
# Total Riders: 88
# Active: 56
# Disabled/Terminated: 20
# Grace Period Expired: 19
# Reactivated: 20
#
# Chatham:
# Total Riders: 21
# Active: 19
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# East Grinstead:
# Total Riders: 15
# Active: 9
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 3
#
# Sevenoaks:
# Total Riders: 26
# Active: 22
# Disabled/Terminated: 3
# Grace Period Expired: 1
# Reactivated: 2
#
# Spalding:
# Total Riders: 5
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Bishops Stortford:
# Total Riders: 54
# Active: 40
# Disabled/Terminated: 7
# Grace Period Expired: 6
# Reactivated: 7
#
# Abingdon:
# Total Riders: 17
# Active: 11
# Disabled/Terminated: 4
# Grace Period Expired: 4
# Reactivated: 4
#
# Chester:
# Total Riders: 45
# Active: 31
# Disabled/Terminated: 9
# Grace Period Expired: 9
# Reactivated: 9
#
# Stratford upon Avon:
# Total Riders: 35
# Active: 24
# Disabled/Terminated: 9
# Grace Period Expired: 8
# Reactivated: 8
#
# Stevenage:
# Total Riders: 9
# Active: 9
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Ely:
# Total Riders: 29
# Active: 22
# Disabled/Terminated: 5
# Grace Period Expired: 4
# Reactivated: 4
#
# Aberdeen:
# Total Riders: 153
# Active: 98
# Disabled/Terminated: 32
# Grace Period Expired: 28
# Reactivated: 29
#
# Hereford:
# Total Riders: 27
# Active: 22
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 2
#
# Bognor Regis:
# Total Riders: 7
# Active: 7
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Shrewsbury:
# Total Riders: 19
# Active: 14
# Disabled/Terminated: 3
# Grace Period Expired: 3
# Reactivated: 3
#
# Yeovil:
# Total Riders: 21
# Active: 16
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Gerrards Cross:
# Total Riders: 5
# Active: 5
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Haverhill:
# Total Riders: 6
# Active: 6
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Deal:
# Total Riders: 9
# Active: 9
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Trowbridge:
# Total Riders: 8
# Active: 6
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Market Harborough:
# Total Riders: 14
# Active: 11
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Whiteley:
# Total Riders: 18
# Active: 14
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Alton:
# Total Riders: 18
# Active: 14
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 2
#
# Dorking:
# Total Riders: 20
# Active: 15
# Disabled/Terminated: 3
# Grace Period Expired: 1
# Reactivated: 2
#
# Slough:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Royal Tunbridge Wells:
# Total Riders: 34
# Active: 30
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 3
#
# Leatherhead:
# Total Riders: 7
# Active: 5
# Disabled/Terminated: 2
# Grace Period Expired: 1
# Reactivated: 1
#
# Ellesmere Port:
# Total Riders: 11
# Active: 10
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Nottingham:
# Total Riders: 26
# Active: 21
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 4
#
# Lincoln:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Newtownabbey:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Dunfermline:
# Total Riders: 2
# Active: 1
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Dublin - Swords & Malahide:
# Total Riders: 49
# Active: 47
# Disabled/Terminated: 2
# Grace Period Expired: 0
# Reactivated: 1
#
# Rushden:
# Total Riders: 18
# Active: 15
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Wellingborough:
# Total Riders: 8
# Active: 6
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Cirencester:
# Total Riders: 12
# Active: 9
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Swansea:
# Total Riders: 35
# Active: 29
# Disabled/Terminated: 5
# Grace Period Expired: 2
# Reactivated: 4
#
# Carlisle:
# Total Riders: 17
# Active: 17
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Dorchester:
# Total Riders: 11
# Active: 9
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Bradford:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# London - Epping Forest:
# Total Riders: 22
# Active: 16
# Disabled/Terminated: 5
# Grace Period Expired: 3
# Reactivated: 3
#
# Liverpool:
# Total Riders: 73
# Active: 46
# Disabled/Terminated: 17
# Grace Period Expired: 12
# Reactivated: 14
#
# Aberystwyth:
# Total Riders: 6
# Active: 3
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Manchester - Altrincham & Sale:
# Total Riders: 54
# Active: 41
# Disabled/Terminated: 12
# Grace Period Expired: 9
# Reactivated: 10
#
# Peacehaven:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Bridgend:
# Total Riders: 23
# Active: 15
# Disabled/Terminated: 5
# Grace Period Expired: 3
# Reactivated: 4
#
# Eastleigh:
# Total Riders: 24
# Active: 18
# Disabled/Terminated: 5
# Grace Period Expired: 5
# Reactivated: 5
#
# King’s Lynn:
# Total Riders: 9
# Active: 6
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# St Helens:
# Total Riders: 20
# Active: 15
# Disabled/Terminated: 4
# Grace Period Expired: 3
# Reactivated: 4
#
# Kirkby:
# Total Riders: 3
# Active: 2
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Deeside:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Rugby:
# Total Riders: 12
# Active: 10
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Livingston:
# Total Riders: 14
# Active: 12
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Wrexham:
# Total Riders: 18
# Active: 12
# Disabled/Terminated: 6
# Grace Period Expired: 4
# Reactivated: 4
#
# Bridgwater:
# Total Riders: 14
# Active: 9
# Disabled/Terminated: 5
# Grace Period Expired: 4
# Reactivated: 4
#
# East Kilbride:
# Total Riders: 8
# Active: 7
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Swindon:
# Total Riders: 19
# Active: 17
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Corby:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Middlesbrough:
# Total Riders: 10
# Active: 8
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Falkirk:
# Total Riders: 7
# Active: 5
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# North Shields:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# New Milton:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Bray:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Stirling:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Yate:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Dublin - Mulhuddart & Blanchardstown:
# Total Riders: 32
# Active: 32
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Tonbridge:
# Total Riders: 20
# Active: 16
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 2
#
# Port Talbot:
# Total Riders: 6
# Active: 3
# Disabled/Terminated: 2
# Grace Period Expired: 1
# Reactivated: 2
#
# Neath:
# Total Riders: 7
# Active: 6
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Torquay:
# Total Riders: 6
# Active: 6
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Cambridge:
# Total Riders: 86
# Active: 67
# Disabled/Terminated: 14
# Grace Period Expired: 10
# Reactivated: 12
#
# Aldershot:
# Total Riders: 9
# Active: 9
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Hitchin:
# Total Riders: 9
# Active: 8
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Salisbury:
# Total Riders: 44
# Active: 30
# Disabled/Terminated: 11
# Grace Period Expired: 10
# Reactivated: 10
#
# Inverness:
# Total Riders: 21
# Active: 13
# Disabled/Terminated: 6
# Grace Period Expired: 5
# Reactivated: 6
#
# Harpenden:
# Total Riders: 10
# Active: 8
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Leixlip:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Redditch:
# Total Riders: 22
# Active: 14
# Disabled/Terminated: 5
# Grace Period Expired: 3
# Reactivated: 3
#
# Hastings:
# Total Riders: 17
# Active: 14
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 2
#
# Berkhamsted:
# Total Riders: 10
# Active: 9
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Highbridge:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Bracknell:
# Total Riders: 6
# Active: 6
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Rotherham:
# Total Riders: 13
# Active: 11
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Luton Central:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Horley:
# Total Riders: 23
# Active: 14
# Disabled/Terminated: 7
# Grace Period Expired: 6
# Reactivated: 6
#
# Waterlooville:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Preston:
# Total Riders: 7
# Active: 3
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 2
#
# Birmingham:
# Total Riders: 20
# Active: 17
# Disabled/Terminated: 2
# Grace Period Expired: 2
# Reactivated: 2
#
# Haywards Heath:
# Total Riders: 10
# Active: 10
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Welwyn Garden City:
# Total Riders: 9
# Active: 8
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Letchworth Garden City:
# Total Riders: 11
# Active: 7
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 2
#
# Watford:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Congleton:
# Total Riders: 7
# Active: 3
# Disabled/Terminated: 4
# Grace Period Expired: 2
# Reactivated: 2
#
# Macclesfield:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Aylesbury:
# Total Riders: 9
# Active: 8
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Dewsbury:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Sheffield:
# Total Riders: 10
# Active: 10
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Newmarket:
# Total Riders: 6
# Active: 5
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Clacton-on-Sea:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Exmouth:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Ipswich:
# Total Riders: 14
# Active: 11
# Disabled/Terminated: 3
# Grace Period Expired: 0
# Reactivated: 2
#
# Lancaster:
# Total Riders: 34
# Active: 23
# Disabled/Terminated: 6
# Grace Period Expired: 5
# Reactivated: 5
#
# Lewes:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Fareham:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Nuneaton:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Andover:
# Total Riders: 15
# Active: 10
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 2
#
# Windsor:
# Total Riders: 7
# Active: 7
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Leicester:
# Total Riders: 7
# Active: 7
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Blackburn:
# Total Riders: 2
# Active: 1
# Disabled/Terminated: 1
# Grace Period Expired: 1
# Reactivated: 1
#
# Dover:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Waterford:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Hamilton:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Derby:
# Total Riders: 30
# Active: 26
# Disabled/Terminated: 3
# Grace Period Expired: 1
# Reactivated: 3
#
# Barnstaple:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Maidenhead:
# Total Riders: 6
# Active: 3
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Gravesend:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Glossop:
# Total Riders: 3
# Active: 1
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Rochdale:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Leigh:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Herne Bay:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Doncaster:
# Total Riders: 1
# Active: 1
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# South Shields:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Sudbury:
# Total Riders: 2
# Active: 2
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Sunderland:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Darlington:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Dunstable:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Newark-on-Trent:
# Total Riders: 4
# Active: 3
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# Worthing:
# Total Riders: 3
# Active: 3
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Loughborough:
# Total Riders: 4
# Active: 4
# Disabled/Terminated: 0
# Grace Period Expired: 0
# Reactivated: 0
#
# Ashford:
# Total Riders: 3
# Active: 2
# Disabled/Terminated: 1
# Grace Period Expired: 0
# Reactivated: 1
#
# === ANALYSIS BY VEHICLE TYPE ===
#
# BI:
# Total Riders: 10026
# Active: 7401
# Disabled/Terminated: 1816
# Grace Period Expired: 1349
# Reactivated: 1518
#
# EB:
# Total Riders: 7863
# Active: 5436
# Disabled/Terminated: 1668
# Grace Period Expired: 1171
# Reactivated: 1275
#
# SC:
# Total Riders: 1444
# Active: 1023
# Disabled/Terminated: 277
# Grace Period Expired: 178
# Reactivated: 209
#
# MV:
# Total Riders: 2810
# Active: 2153
# Disabled/Terminated: 433
# Grace Period Expired: 305
# Reactivated: 354
#
# CB:
# Total Riders: 8
# Active: 3
# Disabled/Terminated: 3
# Grace Period Expired: 2
# Reactivated: 2

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os

# Read the CSV file
df = pd.read_csv('/Users/jono/Downloads/disabled_onboards.csv')

# Clean the data
df['ORDERS_DELIVERED_CUMULATIVE'] = df['ORDERS_DELIVERED_CUMULATIVE'].replace(['\\N', '\\\\N'], 0)
df['ORDERS_DELIVERED_CUMULATIVE'] = pd.to_numeric(df['ORDERS_DELIVERED_CUMULATIVE'], errors='coerce').fillna(0)

# Convert date columns to datetime
date_columns = ['STATUS_DATE', 'ONBOARDING_AT_DATE', 'CREATED_IN_RIDER_ADMIN_AT_DATE']
for col in date_columns:
    df[col] = pd.to_datetime(df[col])

# Function to check if a rider was previously disabled/terminated
def was_previously_disabled(group):
    if len(group) > 1:
        statuses = group['CUR_ADMIN_STATUS'].tolist()
        return any(status in ['DISABLED', 'TERMINATED'] for status in statuses if status != '\\N')
    return False

# Function to analyze rider status
def analyze_rider_status(df):
    # Active riders (status is null)
    active_riders = df[df['CUR_ADMIN_STATUS'] == '\\N']
    
    # Disabled/Terminated riders
    disabled_riders = df[df['CUR_ADMIN_STATUS'].isin(['DISABLED', 'TERMINATED'])]
    
    # Riders with grace period expired
    grace_period_expired = df[
        df['RIDER_ADMIN_STATUS_NOTE'].str.contains('conditional onboarding grace period expired', 
                                                  case=False, na=False)
    ]
    
    # Reactivated riders (previously disabled/terminated, now active)
    reactivated_riders = df.groupby('DRIVER_ID').filter(was_previously_disabled)
    reactivated_riders = reactivated_riders[reactivated_riders['CUR_ADMIN_STATUS'] == '\\N']
    
    return {
        'active': active_riders,
        'disabled': disabled_riders,
        'grace_period_expired': grace_period_expired,
        'reactivated': reactivated_riders
    }

# Function to analyze orders
def analyze_orders(df):
    return {
        'with_orders': df[df['ORDERS_DELIVERED_CUMULATIVE'] > 0],
        'without_orders': df[df['ORDERS_DELIVERED_CUMULATIVE'] == 0]
    }

# Create a directory for results if it doesn't exist
if not os.path.exists('analysis_results'):
    os.makedirs('analysis_results')

# Overall Analysis
status_groups = analyze_rider_status(df)
overall_stats = pd.DataFrame({
    'Metric': ['Total Riders', 'Active Riders', 'Disabled/Terminated Riders', 'Grace Period Expired', 'Reactivated Riders'],
    'Count': [len(df), len(status_groups['active']), len(status_groups['disabled']), 
              len(status_groups['grace_period_expired']), len(status_groups['reactivated'])]
})
overall_stats.to_csv('analysis_results/overall_analysis.csv', index=False)

# Order Analysis
disabled_orders = analyze_orders(status_groups['disabled'])
reactivated_orders = analyze_orders(status_groups['reactivated'])

order_stats = pd.DataFrame({
    'Category': ['Disabled/Terminated - With Orders', 'Disabled/Terminated - Without Orders',
                'Reactivated - With Orders', 'Reactivated - Without Orders'],
    'Count': [len(disabled_orders['with_orders']), len(disabled_orders['without_orders']),
              len(reactivated_orders['with_orders']), len(reactivated_orders['without_orders'])]
})
order_stats.to_csv('analysis_results/order_analysis.csv', index=False)

# Analysis by Onboarding Area
area_stats = []
for area in df['ONBOARDING_AREA'].unique():
    area_df = df[df['ONBOARDING_AREA'] == area]
    area_status = analyze_rider_status(area_df)
    
    area_stats.append({
        'Onboarding Area': area,
        'Total Riders': len(area_df),
        'Active': len(area_status['active']),
        'Disabled/Terminated': len(area_status['disabled']),
        'Grace Period Expired': len(area_status['grace_period_expired']),
        'Reactivated': len(area_status['reactivated'])
    })

area_stats_df = pd.DataFrame(area_stats)
area_stats_df.to_csv('analysis_results/area_analysis.csv', index=False)

# Analysis by Vehicle Type
vehicle_stats = []
for vtype in df['VEHICLE_TYPE'].unique():
    vtype_df = df[df['VEHICLE_TYPE'] == vtype]
    vtype_status = analyze_rider_status(vtype_df)
    
    vehicle_stats.append({
        'Vehicle Type': vtype,
        'Total Riders': len(vtype_df),
        'Active': len(vtype_status['active']),
        'Disabled/Terminated': len(vtype_status['disabled']),
        'Grace Period Expired': len(vtype_status['grace_period_expired']),
        'Reactivated': len(vtype_status['reactivated'])
    })

vehicle_stats_df = pd.DataFrame(vehicle_stats)
vehicle_stats_df.to_csv('analysis_results/vehicle_analysis.csv', index=False)

print("Analysis complete! Results have been saved to the 'analysis_results' directory:")
print("1. overall_analysis.csv - Overall statistics")
print("2. order_analysis.csv - Order completion analysis")
print("3. area_analysis.csv - Analysis by onboarding area")
print("4. vehicle_analysis.csv - Analysis by vehicle type")
print("\nYou can import these CSV files directly into Google Sheets.")
# Out:
# Analysis complete! Results have been saved to the 'analysis_results' directory:
# 1. overall_analysis.csv - Overall statistics
# 2. order_analysis.csv - Order completion analysis
# 3. area_analysis.csv - Analysis by onboarding area
# 4. vehicle_analysis.csv - Analysis by vehicle type
#
# You can import these CSV files directly into Google Sheets.
